# %%
import sys
sys.path.append("../")
from data_read import *
from net import *
import matplotlib.pyplot as plt
import numpy as np

import argparse

import os

# %%
data_loader_caller=data_loader_GoogleEarth('train')
# Out:
# 8750

# %%
input_img,u_list,v_list,template_img=data_loader_caller.data_read_batch(batch_size=4)

# %%
plt.imshow(input_img[0,:,:,:])
plt.show()

# %%
input_img_grey=tf.image.rgb_to_grayscale(input_img)

# %%
plt.imshow(input_img_grey[0,:,:,0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1b692fdf88b9> in <module>
# ----> 1 plt.imshow(input_img_grey[0,:,:,:])
#       2 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# ...
